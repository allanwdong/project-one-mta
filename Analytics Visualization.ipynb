# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %matplotlib inline


df_stat =pd.read_csv("http://web.mta.info/developers/data/nyct/subway/Stations.csv")
columns_stat = ['Station_ID', 'Complex_ID', 'GTFS_Stop_ID', 'Division', 'Line', 'Stop_Name', 'Borough',
              'Daytime_Routes', 'Structure', 'GTFS_Latitude', 'GTFS_Longitude']
df_stat.columns = columns_stat

# %% [markdown]
# ## Geo Analysis Code

# %% [markdown]
# Format of Following Code Structures:
#
# StatLatLon_Time-of-day:
#   List of lists, each element-list in list of list with this format:
#     ['Name of Station-Line Name', Latitude, Longitude, Entries_Diff, Exits_Diff]

# %%
StatLatLonMorn = [
 ['23 St - FM', 40.744081, -73.995657, 400, 763],
 ['23 St - 6', 40.739864, -73.986599, 45, 152],
 ['23 St - RW', 40.741303, -73.989344, 197, 351],
 ['28 St - 6', 40.743070, -73.984264, 80, 180],
 ['28 St - RW', 40.745494, -73.988691, 189, 476],
 ['33 St - 6', 40.746081, -73.982076, 30, 64],   
 ['34 St - Herald Sq', 40.749567, -73.98795, 303, 502],
 ['14 St - Union Sq - 456', 40.734673, -73.989951, 61, 57],
 ['World Trade Ctr', 40.711674, -74.011472, 159, 194],
 ['Park Place', 40.712702, -74.007654, 87, 324]
]

StatLatLonAfter = [
 ['23 St - FM', 40.744081, -73.995657, 513, 452],
 ['23 St - 6', 40.739864, -73.986599, 151, 221],
 ['23 St - RW', 40.741303, -73.989344, 376, 189],
 ['28 St - 6', 40.743070, -73.984264, 197, 332],
 ['28 St - RW', 40.745494, -73.988691, 304, 324],
 ['33 St - 6', 40.746081, -73.982076, 220, 271],   
 ['34 St - Herald Sq', 40.749567, -73.98795, 399, 384],
 ['14 St - Union Sq - 456', 40.734673, -73.989951, 303, 392],
 ['World Trade Ctr', 40.711674, -74.011472, 305, 133],
 ['Park Place', 40.712702, -74.007654, 204, 122]
]

StatLatLonEve = [
 ['23 St - FM', 40.744081, -73.995657, 1054, 518],
 ['23 St - 6', 40.739864, -73.986599, 151, 221],
 ['23 St - RW', 40.741303, -73.989344, 713, 183],
 ['28 St - 6', 40.743070, -73.984264, 364, 242],
 ['28 St - RW', 40.745494, -73.988691, 547, 348],
 ['33 St - 6', 40.746081, -73.982076, 382, 202],   
 ['34 St - Herald Sq', 40.749567, -73.98795, 761, 486],
 ['14 St - Union Sq - 456', 40.734673, -73.989951, 303, 392],
 ['World Trade Ctr', 40.711674, -74.011472, 563, 156],
 ['Park Place', 40.712702, -74.007654, 412, 87]
]




LatMorn = []
LonMorn = []
Size_Entries_Morn = []
Size_Exits_Morn = []
Size_Tot_Morn =[]
for i in StatLatLonMorn:
    LatMorn.append(i[1])
    LonMorn.append(i[2])
    Size_Entries_Morn.append(i[3]/10)
    Size_Exits_Morn.append(i[4]/10)
for a, b in zip(Size_Entries_Morn, Size_Exits_Morn):
    Size_Tot_Morn.append(a + b) 
    
    
LatAfter = []
LonAfter= []
Size_Entries_After = []
Size_Exits_After = []
Size_Tot_After = []
for i in StatLatLonAfter:
    LatAfter.append(i[1])
    LonAfter.append(i[2])
    Size_Entries_After.append(i[3]/10)
    Size_Exits_After.append(i[4]/10) 
for a, b in zip(Size_Entries_After, Size_Exits_After):
    Size_Tot_After.append(a + b) 
    
    
LatEve = []
LonEve = []
Size_Entries_Eve = []
Size_Exits_Eve = []
Size_Tot_Eve = []
for i in StatLatLonEve:
    LatEve.append(i[1])
    LonEve.append(i[2])
    Size_Entries_Eve.append(i[3]/10)
    Size_Exits_Eve.append(i[4]/10)
for a, b in zip(Size_Entries_Eve, Size_Exits_Eve):
    Size_Tot_Eve.append(a + b)

# %% [markdown]
# # Morning Values

# %% [markdown]
# Nick, if you want to mess around with station line colors, you need to create separate lists of stations for each station line above, and separate source and circle commands in the function below
#
# I'm having trouble getting my function to run, if you have the same problem remove my # and ''' comments and it should be fine

# %%
from bokeh.io import show, output_notebook, output_file
from bokeh.models import (
    GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)


# Map coordinates for where to center background map - do not change
nomad = [40.741534, -73.989300]
downtown = [40.712164, -74.009816]

def Mapper(coord, zoom, Lat, Lon, Size_Entries, Size_Exits, Size_Total):

# Takes arguments, returns map plot with circles representing how large Size_Entries/Size_Exits/Size_Total
#  values are

   '''
    Mapper arguments:
        coord - coordinates for where to center background map
        zoom - level of zoom on background map "nomad = 15, downtown = 17"
        Lat - list of latitudes values
        Lon- list of longitude values
        Size_Entries - list of how big Entry value plot glyph should be
        Size_Exit - List of how big Exit value plot glyph should be
        Size_Total - List of how big Total foot traffic value plot glyph should be
    ''' 
    map_options = GMapOptions(lat=coord[0], lng=coord[1], map_type="roadmap", zoom=zoom)

    plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options)

    plot.api_key ='AIzaSyDK_yrBxnXIM0DEV0t9mzRM5j8NSF8wLV8'

# source is where data is collected for circle command below
    
#    source_Entries = ColumnDataSource(data=dict(lat=Lat,lon=Lon, size=Size_Entries))
#    source_Exits = ColumnDataSource(data=dict(lat=Lat,lon=Lon, size=Size_Exits))
    source_Total = ColumnDataSource(data=dict(lat=Lat,lon=Lon, size=Size_Total))


# circle command determines specifics of circle glyphs, change fill_color for color
    
#    circle_Entries = Circle(x="lon", y="lat", size="size", fill_color="red", fill_alpha=0.8, line_color=None)
#    circle_Exits = Circle(x="lon", y="lat", size="size", fill_color="blue", fill_alpha=0.8, line_color=None)
    circle_Tot = Circle(x="lon", y="lat", size="size", fill_color="red", fill_alpha=0.8, line_color=None)


    
    
#    plot.add_glyph(source_Entries, circle_Entries)
#    plot.add_glyph(source_Exits, circle_Exits)
    plot.add_glyph(source_Total, circle_Tot)

#    plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
    output_notebook()
    output_file("gmap_plot.html")


    show(plot)
# Out:
#   File "<ipython-input-124-a88e6bfaea93>", line 36
#     source_Total = ColumnDataSource(data=dict(lat=Lat,lon=Lon, size=Size_Total))
#     ^
# IndentationError: unexpected indent

# %%
Mapper(nomad, 15, LatMorn, LonMorn, Size_Entries_Morn, Size_Exits_Morn, Size_Tot_Morn)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="09d3ccca-6f9e-4954-9912-cca28f73a002">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7bbcda18-82ae-484f-8e74-874ebb72ece9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
Mapper(downtown, 17, LatMorn, LonMorn, Size_Entries_Morn, Size_Exits_Morn, Size_Tot_Morn )
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="51165c83-6eda-4ee9-b92b-6df814dad3af">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0bbccd26-8c5f-4149-b5fd-008d2989b8f3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
Mapper(nomad, 15, LatAfter, LonAfter, Size_Entries_After, Size_Exits_After, Size_Tot_After)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c8757c37-145d-4dee-8bb3-00638cea442c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="de9725cc-cc58-46af-a05c-eec18d7f6f82"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
Mapper(downtown, 17, LatAfter, LonAfter, Size_Entries_After, Size_Exits_After, Size_Tot_After)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4997b3cf-f907-4514-a840-72bbb989f7fb">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a263e7ac-bbfc-48f4-b3ff-bbd1a93f1538"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
Mapper(nomad, 15, LatEve, LonEve, Size_Entries_Eve, Size_Exits_Eve, Size_Tot_Eve)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8f73afb8-b887-453f-8fc7-2db395fbba5c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c07dc84d-3726-4135-92cd-f21204a48d6d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
Mapper(downtown, 17, LatAfter, LonAfter, Size_Entries_After, Size_Exits_After, Size_Tot_After)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2dcc8e2b-b814-4b2b-a678-eff7624a53b3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="aff3f066-bf0e-4963-a053-7484068746a3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...
